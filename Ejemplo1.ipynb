# %%
import pandas as pd
from functions.create_list_df import build_dataframes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 from functions.create_list_df import build_dataframes
#
# ModuleNotFoundError: No module named 'functions'

# %%
d1 = {
    "ds": "pacientes",
    "columns": [
        {
            "name": "id",
            "type": "unique"
        },
        {
            "name": "edad",
            "type": "numeric",
            "values": {
                "min": 1,
                "max": 100,
                "std": 3.48,
                "mean": 46.5
            }
        },
        {
            "name": "genero",
            "type": "category",
            "values": ["Femenino", "Masculino"]
        },
        {
            "name": "primera_cita",
            "type": "date",
            "values": {
                "min": "1930-02-23",
                "max": "2024-06-04"
            }
        }
    ],
    "random": False
}

# %%
d2 = {
    "ds": "doctores",
    "columns": [
        {
            "name": "id", 
            "type": "unique"
        },
        {
            "name": "fecha_ingreso",
            "type": "date",
            "values": {
                "min": "2000-02-23",
                "max": "2024-03-04"
            }
        },
        {
            "name": "departamento",
            "type": "category",
            "values": ["MGeneral", "Cirugía", "Oncología", "Pediatría"]
        },
        {
            "name": "hospital",
            "type": "foreign",
            "values": "hospitales.nombre"
        }
    ],
    "random": False
}

# %%
d3 = {
    "ds": "hospitales",
    "columns": [
        {
            "name": "nombre",
            "type": "unique",
        },
        {
            "name": "ciudad",
            "type": "category",
            "values": ["SP", "T", "C", "M", "SB", "PC"]
        },
        {
            "name": "cantidad_empleados",
            "type": "numeric",
            "values": {
                "min": 800,
                "max": 10000
            }
        }
    ],
    "random": True,
    "random_rows": 1500
}

# %%
d4 = {
    "ds": "citas",
    "columns": [
        {
            "name": "doctor",
            "type": "foreign",
            "values": "doctores.id"
        },
        {
            "name": "paciente",
            "type": "foreign",
            "values": "pacientes.id"
        },
        {
            "name": "fecha_cita",
            "type": "date",
            "values": {
                "min":  "1930-02-23",
                "max": "2024-06-04"
            }
        }, 
        {
            "name": "enfermedad",
            "type": "foreign",
            "values": "enfermedades.id"
        }
    ],
    "random": True,
    "random_rows": 10000000
}

# %%
d5 = {
    "ds": "enfermedades",
    "columns": [
        {
            "name": "id",
            "type": "unique",
        },
        {
            "name": "estado",
            "type": "category",
            "values": ["leve", "moderado", "grave"]
        },
        {
            "name": "porcentaje_recuperacion",
            "type": "numeric",
            "values": {
                "min": 1,
                "max": 80.97,
                "std": 3.48,
                "mean": 75.9
            }
        }
    ],
    "random": False
}
